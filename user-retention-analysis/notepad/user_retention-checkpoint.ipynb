# %% [markdown]
# # **USER RETENTION ANALYSIS**

# %% [markdown]
# ## import package

# %%
# !pip install pandas
# !pip install numpy
# !pip install datetime
import pandas as pd
import numpy as np
import datetime as dt
# Out:
# ...
#
#    ---------------------------------------- 0/2 [zope.interface]
#    ---------------------------------------- 0/2 [zope.interface]
#    ---------------------------------------- 0/2 [zope.interface]
#    ---------------------------------------- 0/2 [zope.interface]
#    ---------------------------------------- 0/2 [zope.interface]
#    ---------------------------------------- 0/2 [zope.interface]
#    ---------------------------------------- 0/2 [zope.interface]
#    ---------------------------------------- 0/2 [zope.interface]
#    ---------------------------------------- 0/2 [zope.interface]
#    -------------------- ------------------- 1/2 [datetime]
#    ---------------------------------------- 2/2 [datetime]
#
# ...

# %%
df = pd.read_csv('\Users\fikri\Documents\data_analis\user_retention_analysis\data\raw\online_retail_data.csv', header=0)
df
# Out:
#   Cell In[5], line 1
#     df = pd.read_csv('\Users\fikri\Documents\data_analis\user_retention_analysis\data\raw\online_retail_data.csv', header=0)
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 0-1: truncated \UXXXXXXXX escape
